# %%
import pandas as pd
import copy
import requests
from tqdm.notebook import tqdm
from tqdm import tqdm
import numpy as np
from selenium import webdriver
from selenium.webdriver.common.by import By          # - 정보 획득
from selenium.webdriver.common.keys import Keys
# from engine_connect import create_engine_connect, db_connection
from sqlalchemy import create_engine
import os
import re
import time
from bs4 import BeautifulSoup
import warnings
import pymysql
import math
warnings.filterwarnings(action='ignore')
from selenium.webdriver.common.action_chains import ActionChains
import json


import time
import datetime as dt # 사용시 datetime.dt 로 사용 # 현재 시간 사용
from datetime import datetime # 사용시 함수로 바로 사용 #-> 시간 비교

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rc('font', family='NanumBarunGothic') # 혹은 다른 설치한 Nanum 폰트 사용
plt.rcParams.update({'font.family': 'NanumBarunGothic'})

import scipy
import scipy.stats as stats
# 경고창 무시
import warnings
warnings.filterwarnings('ignore')

# %%
### 한글 폰트 설치
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import platform

path = 'c:/Windows/Fonts/malgun.ttf'  # 또는 나눔고딕: 'c:/Windows/Fonts/NanumGothic.ttf'
font_name = font_manager.FontProperties(fname=path).get_name()
rc('font', family=font_name)

# %%
directory = os.getcwd()
print("Current working directory : ", directory)

#수집날짜
folder_date = str(dt.datetime.now().date())
folder_date = re.sub("-", ".", folder_date)
today = re.sub("\.", "", folder_date)
print('오늘 날짜 : ', folder_date)

now = dt.datetime.now()
print('현재 시간 : ', now)
# Out:
# Current working directory :  C:\Develops\Competetion_Gangneung_vision_planning
# 오늘 날짜 :  2024.08.06
# 현재 시간 :  2024-08-06 21:34:10.914742

# %% [markdown]
# ### 강릉시 시장 데이터 조사

# %%
df_jumunjin_flea_market = pd.read_csv(f"{directory}/data/강원도 강릉시_주문진좌판풍물시장_20211210.csv", encoding='euc-kr')
df_jumunjin_total_market = pd.read_csv(f"{directory}/data/강원도 강릉시_주문진종합시장_20211210.csv", encoding='euc-kr')
df_jumunjin_sea_market = pd.read_csv(f"{directory}/data/강원도 강릉시_주문진수산시장_20211210.csv", encoding='euc-kr')
df_jumunjin_dry_market = pd.read_csv(f"{directory}/data/강원도 강릉시_주문진건어물시장_20211210.csv", encoding='cp949')
df_east_market = pd.read_csv(f"{directory}/data/강원도 강릉시_동부시장_20211210.csv", encoding='euc-kr')
df_west_market = pd.read_csv(f"{directory}/data/강원도 강릉시_서부시장_20211210.csv", encoding='euc-kr')
df_center_market = pd.read_csv(f"{directory}/data/강원도 강릉시_중앙시장_20211210.csv", encoding='euc-kr')

# %%
df_market_info = pd.concat([df_jumunjin_flea_market,df_jumunjin_total_market,df_jumunjin_sea_market,df_jumunjin_dry_market,df_east_market,df_west_market,df_center_market], ignore_index = True)
df_market_info
# Out:
#       연번      전통시장명      상호명         운영시간   업종구분                    도로명 주소  \
# 0      1  주문진좌판풍물시장  회 뜨는 장소  08:00-19:30     기타  강원도 강릉시 주문진읍 해안로 1758-10
# 1      2  주문진좌판풍물시장  회 뜨는 장소  08:00-19:30     기타  강원도 강릉시 주문진읍 해안로 1758-10
# 2      3  주문진좌판풍물시장  회 뜨는 장소  08:00-19:30     기타  강원도 강릉시 주문진읍 해안로 1758-10
# 3      4  주문진좌판풍물시장     쌍둥이네  08:00-19:30    수산물  강원도 강릉시 주문진읍 해안로 1758-10
# 4      5  주문진좌판풍물시장     혁범이네  08:00-19:30    수산물  강원도 강릉시 주문진읍 해안로 1758-10
# ..   ...        ...      ...          ...    ...                       ...
# 907  237       중앙시장     도마횟집  11:00-00:00    수산물                       NaN
# 908  238       중앙시장     혜정상회  09:00-18:00    수산물                       NaN
# 909  239       중앙시장   강릉중앙물회  09:00-18:00    수산물                       NaN
# 910  240       중앙시장     상지식품  09:00-18:00  마트/식품                       NaN
# 911  241       중앙시장     평남상회  09:00-18:00    수산물                       NaN
#
# ...

# %%
df_market_info.isnull().sum()
# Out:
# 연번           0
# 전통시장명        0
# 상호명          0
# 운영시간       160
# 업종구분         0
# 도로명 주소     788
# 지번 주소      788
# 전화번호       527
# 위도           0
# 경도           0
# 데이터기준      551
# 도로명주소      125
# 지번주소       125
# 데이터기준일자    361
# dtype: int64

# %%
df_market_info.duplicated().sum()
# Out:
# 1
